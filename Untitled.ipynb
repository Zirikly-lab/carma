# %%
import pandas as pd
import glob
import os

path = '/SEAS/home/g21775526/code/aladdin/data/pretraining/youtube-scraper/aladdin-pretraining-corpus'

files = [f for f in os.listdir(path) if f.endswith('.csv')]
df = pd.concat((pd.read_csv(path+"/"+f) for f in files), ignore_index=True)
df.to_csv('/SEAS/home/g21775526/code/salm/da')
# Out:
#                                            video_url  \
# 0        https://www.youtube.com/watch?v=ltD4UWG_LsM
# 1        https://www.youtube.com/watch?v=ltD4UWG_LsM
# 2        https://www.youtube.com/watch?v=ltD4UWG_LsM
# 3        https://www.youtube.com/watch?v=ltD4UWG_LsM
# 4        https://www.youtube.com/watch?v=ltD4UWG_LsM
# ...                                              ...
# 5429366  https://www.youtube.com/watch?v=OWtpUD8YHkw
# 5429367  https://www.youtube.com/watch?v=OWtpUD8YHkw
# 5429368  https://www.youtube.com/watch?v=OWtpUD8YHkw
# 5429369  https://www.youtube.com/watch?v=OWtpUD8YHkw
# 5429370  https://www.youtube.com/watch?v=OWtpUD8YHkw
#
#                                                    comment  \
# 0                            اللهم صل على محمد وال محمد 💞😔
# 1        نبي مقلب في عدنااان\n\nمقلب عادل رمى نفسه من ا...
# 2                     بشاير نبي مقلب بعدنان الي بصفي الايك
# 3        نبي مقلب في حنان تقولون لها رح تنعزلين من اليو...
# ...
